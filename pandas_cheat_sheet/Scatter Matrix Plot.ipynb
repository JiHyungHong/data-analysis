# %% [markdown]
# # Scatter Matrix Plot
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#plotting-tools

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from pandas.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd']) 
df.head()
# Out:
#           a         b         c         d
# 0 -0.740948  0.117910  0.307961 -0.344756
# 1 -3.537055 -0.246478  0.795667  0.744125
# 2 -1.061206 -1.513162  1.151930  1.318025
# 3 -0.756372 -0.571236 -0.973121  0.377709
# 4 -0.474498  1.066873 -1.038706  0.233790

# %%
# kde - 커널밀도함수
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde') # alpha:투명도
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x120c876a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120fddf60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12100f4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121036a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12105dfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12108e588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1210b5b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1210e50f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1210e5128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121134ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121164160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12118d6d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1211b5c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1211e4208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12120b780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121236cf8>]],
#       dtype=object)
