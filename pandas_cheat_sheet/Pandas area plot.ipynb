# %% [markdown]
# # area plot
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.596296  0.741627  0.325611  0.189591
# 1  0.292785  0.263297  0.284786  0.473030
# 2  0.491808  0.263916  0.293886  0.706644
# 3  0.188076  0.783865  0.681643  0.893307
# 4  0.022216  0.000123  0.538178  0.098546

# %%
df.plot(grid=True)

# %%
df.plot.area(stacked=False, grid=True) # default로 stacked는 True이다
